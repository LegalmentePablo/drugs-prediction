# %% [markdown]
# # Optimización Bayesiana y Selección del Modelo Final
#
# Este notebook realiza optimización avanzada de hiperparámetros con Optuna, validación robusta (CV anidada), ensembles y selección del modelo final para la predicción de consumo de sustancias.
#
# ## Tabla de Contenidos
# - Caso 0 — Preparación e Importaciones
# - Caso 1 — Carga de Datos y Verificaciones
# - Caso 2 — Esquema de Validación Robusta (CV anidada)
# - Caso 3 — Espacios de Hiperparámetros por Modelo
# - Caso 4 — Optimización Multi‑Objetivo con Optuna (F1 + ROC‑AUC)
# - Caso 5 — Validación Externa y Estabilidad de Métricas
# - Caso 6 — Ensembles (Voting, Weighted Voting, Stacking) y Diversidad
# - Caso 7 — Selección del Modelo Final y Artefactos para Producción
# - Resumen de Decisiones Técnicas
#
# Nota: TimeSeriesSplit no aplica aquí; los datos son transversales de encuesta (ENCSPA 2019). Se utiliza StratifiedKFold con semillas controladas para garantizar reproducibilidad y equilibrio por clase.

# %% [markdown]
# ## Caso 0 — Preparación e Importaciones
# Importamos librerías y fijamos semillas. Se incluyen `xgboost`, `lightgbm` y `randomforest` como modelos base, y soporte opcional para `catboost`. Para Optuna se usa TPE (búsqueda bayesiana) y un pruner mediano para acelerar convergencia.

# %%
# Imports y configuración
import pandas as pd
import numpy as np
import warnings, time, json
from pathlib import Path
import joblib
from datetime import datetime

from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier, VotingClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression

import optuna
from optuna.samplers import TPESampler
from optuna.pruners import MedianPruner

import xgboost as xgb
import lightgbm as lgb

try:
    from catboost import CatBoostClassifier
    CATBOOST_AVAILABLE = True
except Exception:
    CATBOOST_AVAILABLE = False

warnings.filterwarnings('ignore')
SEED = 42
np.random.seed(SEED)
print("Librerías importadas y configuración lista")
# Out:
# Librerías importadas y configuración lista

# %% [markdown]
# ## Caso 1 — Carga de Datos y Verificaciones
# Se cargan los datos procesados del notebook 03 (`data/processed`). Si no están disponibles, se aplica un **pipeline básico** con imputación, encoding y escalado. Se conserva el balance de train (SMOTE) cuando existe para que el tuning refleje un conjunto equilibrado.

# %%
# Carga de datos procesados (del notebook 03) con fallback básico
print("Cargando datos procesados ...")
paths = Path('../data/processed')
use_smote = True

try:
    X_train_final = pd.read_pickle(paths/'X_train_balanced.pkl')
    y_train_final = pd.read_pickle(paths/'y_train_balanced.pkl')
    X_test_final = pd.read_pickle(paths/'X_test_transformed.pkl')
    y_test_final = pd.read_pickle(paths/'y_test.pkl')
    feature_names = pd.read_pickle(paths/'feature_names.pkl')
    print(f"Datos cargados: Train={X_train_final.shape}, Test={X_test_final.shape}, Features={len(feature_names)}")
except Exception as e:
    print(f"Fallo al cargar datos procesados: {e}")
    print("Usando pipeline básico como fallback (SIN SMOTE)")
    df = pd.read_csv('../data/g_capitulos.csv')
    target_var = 'G_11_F'
    categorical_features = ['G_01', 'G_02', 'G_03', 'G_04', 'G_05']
    numerical_features = ['G_06_A','G_06_B','G_06_C','G_06_D','G_07','G_08_A','G_08_B','G_01_A','G_02_A']
    df_clean = df[df[target_var].isin([1,2])].copy()
    X = df_clean[categorical_features + numerical_features]
    y = (df_clean[target_var] == 1).astype(int)
    from sklearn.impute import SimpleImputer
    from sklearn.preprocessing import LabelEncoder, StandardScaler
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=SEED, stratify=y)
    cat_imputer = SimpleImputer(strategy='most_frequent')
    num_imputer = SimpleImputer(strategy='median')
    X_train[categorical_features] = cat_imputer.fit_transform(X_train[categorical_features])
    X_test[categorical_features] = cat_imputer.transform(X_test[categorical_features])
    X_train[numerical_features] = num_imputer.fit_transform(X_train[numerical_features])
    X_test[numerical_features] = num_imputer.transform(X_test[numerical_features])
    le_dict = {}
    for col in categorical_features:
        le = LabelEncoder()
        X_train[col] = le.fit_transform(X_train[col].astype(str))
        X_test[col] = le.transform(X_test[col].astype(str))
        le_dict[col] = le
    scaler = StandardScaler()
    X_train[numerical_features] = scaler.fit_transform(X_train[numerical_features])
    X_test[numerical_features] = scaler.transform(X_test[numerical_features])
    X_train_final, y_train_final = X_train, y_train
    X_test_final, y_test_final = X_test, y_test
    feature_names = X_train_final.columns.tolist()
    use_smote = False

print("Verificación final:")
print(f"Train balance (positivos): {y_train_final.mean():.3f} | Test balance: {y_test_final.mean():.3f}")
# Out:
# Cargando datos procesados ...
# Datos cargados: Train=(31442, 14), Test=(4686, 14), Features=14
# Verificación final:
# Train balance (positivos): 0.500 | Test balance: 0.161

# %% [markdown]
# ## Caso 2 — Esquema de Validación Robusta (CV anidada)
# Se usa validación cruzada **anidada**:
# - `inner_cv` (3 folds): tuning de hiperparámetros y estimación de métricas promedio.
# - `outer_cv` (5 folds): evaluación externa para medir **estabilidad** (media y desviación estándar).
# Se reportan `F1` y `ROC‑AUC` con probabilidades cuando el modelo lo permite.

# %%
# Configuración de validación y métricas
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
inner_cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=SEED+1)

def cv_metrics(estimator, X, y, cv):
    f1s, aucs = [], []
    for train_idx, val_idx in cv.split(X, y):
        X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]
        est = estimator
        est.fit(X_tr, y_tr)
        y_pred = est.predict(X_val)
        f1s.append(f1_score(y_val, y_pred))
        if hasattr(est, 'predict_proba'):
            y_prob = est.predict_proba(X_val)[:,1]
            aucs.append(roc_auc_score(y_val, y_prob))
        else:
            aucs.append(np.nan)
    return float(np.nanmean(f1s)), float(np.nanmean(aucs)), f1s, aucs

print("Validación configurada: outer=5 folds, inner=3 folds")
# Out:
# Validación configurada: outer=5 folds, inner=3 folds

# %% [markdown]
# ## Caso 3 — Espacios de Hiperparámetros por Modelo
# Se definen espacios bayesianos con rangos razonables para cada modelo. La función `make_estimator` construye el estimador con parámetros sugeridos por Optuna.

# %%
# Espacios de hiperparámetros
def suggest_params(trial, model_name):
    if model_name == 'xgb':
        return {
            'n_estimators': trial.suggest_int('n_estimators', 150, 500),
            'max_depth': trial.suggest_int('max_depth', 3, 8),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'subsample': trial.suggest_float('subsample', 0.6, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
            'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0.5, 2.0),
            'min_child_weight': trial.suggest_float('min_child_weight', 1.0, 10.0)
        }
    elif model_name == 'lgb':
        return {
            'n_estimators': trial.suggest_int('n_estimators', 150, 500),
            'num_leaves': trial.suggest_int('num_leaves', 20, 120),
            'max_depth': trial.suggest_int('max_depth', 3, 8),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'subsample': trial.suggest_float('subsample', 0.6, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
            'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
            'min_child_samples': trial.suggest_int('min_child_samples', 10, 100)
        }
    elif model_name == 'rf':
        max_feat = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])
        return {
            'n_estimators': trial.suggest_int('n_estimators', 200, 600),
            'max_depth': trial.suggest_categorical('max_depth', [None, 10, 15, 20, 25, 30]),
            'min_samples_split': trial.suggest_int('min_samples_split', 2, 20),
            'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
            'max_features': max_feat,
            'bootstrap': trial.suggest_categorical('bootstrap', [True, False])
        }
    elif model_name == 'cat' and CATBOOST_AVAILABLE:
        return {
            'iterations': trial.suggest_int('iterations', 200, 600),
            'depth': trial.suggest_int('depth', 4, 10),
            'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
            'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1.0, 10.0),
            'subsample': trial.suggest_float('subsample', 0.6, 1.0)
        }
    else:
        raise ValueError(f"Modelo no soportado en espacio: {model_name}")

def make_estimator(model_name, params):
    if model_name == 'xgb':
        return xgb.XGBClassifier(random_state=SEED, eval_metric='logloss', verbosity=0, n_jobs=-1, **params)
    elif model_name == 'lgb':
        return lgb.LGBMClassifier(random_state=SEED, verbose=-1, force_col_wise=True, **params)
    elif model_name == 'rf':
        return RandomForestClassifier(random_state=SEED, n_jobs=-1, **params)
    elif model_name == 'cat' and CATBOOST_AVAILABLE:
        return CatBoostClassifier(random_state=SEED, verbose=False, loss_function='Logloss', **params)
    else:
        raise ValueError(f"Modelo no soportado: {model_name}")

print("Espacios de hiperparámetros listos")
# Out:
# Espacios de hiperparámetros listos

# %% [markdown]
# ## Caso 4 — Optimización Multi‑Objetivo con Optuna (F1 + ROC‑AUC)
# Se crea un estudio con dos objetivos a maximizar: `F1` y `ROC‑AUC`. Se usa **TPE** con `MedianPruner` para detener configuraciones poco prometedoras. Se ejecutan **≥220 trials** por modelo.

# %%
# Optuna: estudio multi-objetivo (F1 y ROC-AUC) por modelo
def run_optuna_for_model(model_name, n_trials=220):
    sampler = TPESampler(seed=SEED)
    pruner = MedianPruner(n_startup_trials=30)
    study = optuna.create_study(directions=['maximize','maximize'], sampler=sampler, pruner=pruner)
    def objective(trial):
        params = suggest_params(trial, model_name)
        est = make_estimator(model_name, params)
        f1_mean, auc_mean, f1s, aucs = cv_metrics(est, X_train_final, y_train_final, inner_cv)
        trial.set_user_attr('f1s', f1s)
        trial.set_user_attr('aucs', aucs)
        trial.set_user_attr('params', params)
        return f1_mean, auc_mean
    start = time.time()
    study.optimize(objective, n_trials=n_trials, n_jobs=1)
    duration = time.time() - start
    print(f"Optuna {model_name}: {len(study.trials)} trials en {duration:.1f}s")
    return study

# Top 3 modelos del commit anterior (04): LightGBM, XGBoost, RandomForest
selected_models = ['lgb', 'xgb', 'rf']
studies = {}
for m in selected_models:
    studies[m] = run_optuna_for_model(m, n_trials=220)

print("Optimización completa para modelos seleccionados")
# Out:
# [I 2025-10-27 23:22:31,159] A new study created in memory with name: no-name-49c1a788-7569-4748-8141-50a2258dbfff
# [I 2025-10-27 23:22:32,656] Trial 0 finished with values: [0.9239250026845865, 0.9770765355587431] and parameters: {'n_estimators': 281, 'num_leaves': 116, 'max_depth': 7, 'learning_rate': 0.07661100707771368, 'subsample': 0.6624074561769746, 'colsample_bytree': 0.662397808134481, 'reg_alpha': 0.05808361216819946, 'reg_lambda': 0.8661761457749352, 'min_child_samples': 64}.
# [I 2025-10-27 23:22:33,981] Trial 1 finished with values: [0.92324989083568, 0.9764302482545807] and parameters: {'n_estimators': 398, 'num_leaves': 22, 'max_depth': 8, 'learning_rate': 0.16967533607196555, 'subsample': 0.6849356442713105, 'colsample_bytree': 0.6727299868828402, 'reg_alpha': 0.18340450985343382, 'reg_lambda': 0.3042422429595377, 'min_child_samples': 57}.
# [I 2025-10-27 23:22:35,186] Trial 2 finished with values: [0.9155195249142046, 0.9686364062494098] and parameters: {'n_estimators': 301, 'num_leaves': 49, 'max_depth': 6, 'learning_rate': 0.01607123851203988, 'subsample': 0.7168578594140873, 'colsample_bytree': 0.7465447373174767, 'reg_alpha': 0.45606998421703593, 'reg_lambda': 0.7851759613930136, 'min_child_samples': 28}.
# [I 2025-10-27 23:22:35,957] Trial 3 finished with values: [0.9217024675477545, 0.975105086551829] and parameters: {'n_estimators': 330, 'num_leaves': 79, 'max_depth': 3, 'learning_rate': 0.07896186801026692, 'subsample': 0.6682096494749166, 'colsample_bytree': 0.6260206371941118, 'reg_alpha': 0.9488855372533332, 'reg_lambda': 0.9656320330745594, 'min_child_samples': 83}.
# [I 2025-10-27 23:22:37,012] Trial 4 finished with values: [0.9240393579002841, 0.9763559431256715] and parameters: {'n_estimators': 256, 'num_leaves': 29, 'max_depth': 7, 'learning_rate': 0.044684675025045834, 'subsample': 0.6488152939379115, 'colsample_bytree': 0.798070764044508, 'reg_alpha': 0.034388521115218396, 'reg_lambda': 0.9093204020787821, 'min_child_samples': 33}.
# [I 2025-10-27 23:22:38,588] Trial 5 finished with values: [0.9239462299438935, 0.9765744754059581] and parameters: {'n_estimators': 382, 'num_leaves': 51, 'max_depth': 6, 'learning_rate': 0.06420330336297862, 'subsample': 0.6739417822102108, 'colsample_bytree': 0.9878338511058234, 'reg_alpha': 0.7751328233611146, 'reg_lambda': 0.9394989415641891, 'min_child_samples': 91}.
# [I 2025-10-27 23:22:39,458] Trial 6 finished with values: [0.90940832860788, 0.9637478062422046] and parameters: {'n_estimators': 359, 'num_leaves': 113, 'max_depth': 3, 'learning_rate': 0.01947558230629543, 'subsample': 0.6180909155642152, 'colsample_bytree': 0.7301321323053057, 'reg_alpha': 0.388677289689482, 'reg_lambda': 0.2713490317738959, 'min_child_samples': 85}.
# [I 2025-10-27 23:22:40,496] Trial 7 finished with values: [0.9157148363217505, 0.9677880052712858] and parameters: {'n_estimators': 275, 'num_leaves': 48, 'max_depth': 6, 'learning_rate': 0.016149614799999188, 'subsample': 0.9208787923016158, 'colsample_bytree': 0.6298202574719083, 'reg_alpha': 0.9868869366005173, 'reg_lambda': 0.7722447692966574, 'min_child_samples': 28}.
# [I 2025-10-27 23:22:41,185] Trial 8 finished with values: [0.9248332700409708, 0.976867110979847] and parameters: {'n_estimators': 151, 'num_leaves': 102, 'max_depth': 7, 'learning_rate': 0.11935262708510537, 'subsample': 0.9085081386743783, 'colsample_bytree': 0.6296178606936361, 'reg_alpha': 0.3584657285442726, 'reg_lambda': 0.11586905952512971, 'min_child_samples': 88}.
# [I 2025-10-27 23:22:42,012] Trial 9 finished with values: [0.9156393867338898, 0.9688702410141422] and parameters: {'n_estimators': 368, 'num_leaves': 53, 'max_depth': 3, 'learning_rate': 0.028797752657070342, 'subsample': 0.7300733288106989, 'colsample_bytree': 0.8918424713352255, 'reg_alpha': 0.6375574713552131, 'reg_lambda': 0.8872127425763265, 'min_child_samples': 52}.
# [I 2025-10-27 23:22:42,616] Trial 10 finished with values: [0.9228561089254529, 0.9764449328893384] and parameters: {'n_estimators': 157, 'num_leaves': 92, 'max_depth': 5, 'learning_rate': 0.24184871356487458, 'subsample': 0.9916893928795038, 'colsample_bytree': 0.876098829427658, 'reg_alpha': 0.2579269526014921, 'reg_lambda': 0.011114384822711279, 'min_child_samples': 98}.
# [I 2025-10-27 23:22:46,194] Trial 11 finished with values: [0.9223183004646271, 0.9743772097799085] and parameters: {'n_estimators': 498, 'num_leaves': 120, 'max_depth': 8, 'learning_rate': 0.13031745397329927, 'subsample': 0.849109076872556, 'colsample_bytree': 0.6082728941092255, 'reg_alpha': 0.041211173848960614, 'reg_lambda': 0.0110465647549646, 'min_child_samples': 63}.
# [I 2025-10-27 23:22:47,019] Trial 12 finished with values: [0.9243885125723798, 0.9769322438290086] and parameters: {'n_estimators': 155, 'num_leaves': 100, 'max_depth': 7, 'learning_rate': 0.11081377563672132, 'subsample': 0.8117828749120539, 'colsample_bytree': 0.6915762229955171, 'reg_alpha': 0.6276429452559498, 'reg_lambda': 0.47428268266554097, 'min_child_samples': 71}.
# [I 2025-10-27 23:22:47,780] Trial 13 finished with values: [0.9228508266965454, 0.9763495888557667] and parameters: {'n_estimators': 213, 'num_leaves': 79, 'max_depth': 5, 'learning_rate': 0.2993501632241744, 'subsample': 0.8900861018982393, 'colsample_bytree': 0.6880512449263219, 'reg_alpha': 0.2579652222771262, 'reg_lambda': 0.22599908527558787, 'min_child_samples': 76}.
# [I 2025-10-27 23:22:48,856] Trial 14 finished with values: [0.9228335949066223, 0.9755294671558925] and parameters: {'n_estimators': 213, 'num_leaves': 100, 'max_depth': 7, 'learning_rate': 0.041165076081724504, 'subsample': 0.9992813887590825, 'colsample_bytree': 0.786992384012982, 'reg_alpha': 0.36950297159667705, 'reg_lambda': 0.5705130146362531, 'min_child_samples': 47}.
# [I 2025-10-27 23:22:50,213] Trial 15 finished with values: [0.9068801851596975, 0.9605696191880888] and parameters: {'n_estimators': 450, 'num_leaves': 108, 'max_depth': 4, 'learning_rate': 0.010380836837556022, 'subsample': 0.9258360514720572, 'colsample_bytree': 0.6604696711478142, 'reg_alpha': 0.585272218467161, 'reg_lambda': 0.5093352874454425, 'min_child_samples': 98}.
# [I 2025-10-27 23:22:51,527] Trial 16 finished with values: [0.922864590246613, 0.9766493214693797] and parameters: {'n_estimators': 209, 'num_leaves': 68, 'max_depth': 8, 'learning_rate': 0.09874248947009587, 'subsample': 0.7911302960155628, 'colsample_bytree': 0.7158754438303072, 'reg_alpha': 0.1330156809447968, 'reg_lambda': 0.09714908721093846, 'min_child_samples': 11}.
# [I 2025-10-27 23:22:52,746] Trial 17 finished with values: [0.9229212115619941, 0.9765313564164093] and parameters: {'n_estimators': 246, 'num_leaves': 89, 'max_depth': 7, 'learning_rate': 0.1810482911009809, 'subsample': 0.7689740652601629, 'colsample_bytree': 0.8604035330355402, 'reg_alpha': 0.8139937055778315, 'reg_lambda': 0.6451664073326272, 'min_child_samples': 70}.
# [I 2025-10-27 23:22:53,411] Trial 18 finished with values: [0.9222940770054825, 0.9747432305905951] and parameters: {'n_estimators': 175, 'num_leaves': 64, 'max_depth': 5, 'learning_rate': 0.06764685071463597, 'subsample': 0.8562989934645472, 'colsample_bytree': 0.9723912628774799, 'reg_alpha': 0.5041804166278286, 'reg_lambda': 0.3644474777814951, 'min_child_samples': 82}.
# [I 2025-10-27 23:22:54,978] Trial 19 finished with values: [0.9235476336588663, 0.9763437920277602] and parameters: {'n_estimators': 309, 'num_leaves': 84, 'max_depth': 7, 'learning_rate': 0.14584903771504842, 'subsample': 0.9283991018687957, 'colsample_bytree': 0.6020756964195577, 'reg_alpha': 0.2415834261767888, 'reg_lambda': 0.1695815293877519, 'min_child_samples': 42}.
# [I 2025-10-27 23:22:56,255] Trial 20 finished with values: [0.9246378819394079, 0.9767925080404648] and parameters: {'n_estimators': 427, 'num_leaves': 120, 'max_depth': 4, 'learning_rate': 0.08835491553387982, 'subsample': 0.9684210463115843, 'colsample_bytree': 0.7636004284281295, 'reg_alpha': 0.31986772059148716, 'reg_lambda': 0.39723230573194546, 'min_child_samples': 64}.
# [I 2025-10-27 23:22:57,022] Trial 21 finished with values: [0.9248957774392679, 0.976769641476453] and parameters: {'n_estimators': 150, 'num_leaves': 101, 'max_depth': 7, 'learning_rate': 0.12234723811550699, 'subsample': 0.83855013784623, 'colsample_bytree': 0.6574777270458487, 'reg_alpha': 0.6605241956484148, 'reg_lambda': 0.6705031350596276, 'min_child_samples': 89}.
# [I 2025-10-27 23:22:58,268] Trial 22 finished with values: [0.9247382827522147, 0.976833111719276] and parameters: {'n_estimators': 188, 'num_leaves': 105, 'max_depth': 8, 'learning_rate': 0.05201397494349621, 'subsample': 0.6123469471321029, 'colsample_bytree': 0.830676410666, 'reg_alpha': 0.07918114278487254, 'reg_lambda': 0.7344979290960285, 'min_child_samples': 16}.
# [I 2025-10-27 23:22:59,657] Trial 23 finished with values: [0.9228530748598156, 0.9755236043145573] and parameters: {'n_estimators': 334, 'num_leaves': 111, 'max_depth': 6, 'learning_rate': 0.032659051128022726, 'subsample': 0.7461687797777014, 'colsample_bytree': 0.9171495780540042, 'reg_alpha': 0.7251615496994137, 'reg_lambda': 0.8279327924779691, 'min_child_samples': 40}.
# [I 2025-10-27 23:23:00,785] Trial 24 finished with values: [0.9249462310703812, 0.9769158248370132] and parameters: {'n_estimators': 243, 'num_leaves': 97, 'max_depth': 7, 'learning_rate': 0.059966369796114485, 'subsample': 0.8240704533457542, 'colsample_bytree': 0.645809678372447, 'reg_alpha': 0.17196020744635604, 'reg_lambda': 0.6638935316318397, 'min_child_samples': 58}.
# [I 2025-10-27 23:23:01,979] Trial 25 finished with values: [0.9214055916778358, 0.9748156172504233] and parameters: {'n_estimators': 296, 'num_leaves': 94, 'max_depth': 6, 'learning_rate': 0.0304062556102333, 'subsample': 0.8208301246888957, 'colsample_bytree': 0.6960571958355273, 'reg_alpha': 0.14660535410795342, 'reg_lambda': 0.4823155513101983, 'min_child_samples': 58}.
# [I 2025-10-27 23:23:03,246] Trial 26 finished with values: [0.9248869022214118, 0.9768633399507788] and parameters: {'n_estimators': 258, 'num_leaves': 39, 'max_depth': 8, 'learning_rate': 0.05201592223794252, 'subsample': 0.7988437478533329, 'colsample_bytree': 0.7023021210553261, 'reg_alpha': 0.006067516320621025, 'reg_lambda': 0.648282073793899, 'min_child_samples': 71}.
# [I 2025-10-27 23:23:04,246] Trial 27 finished with values: [0.9178765629803682, 0.9714860667814896] and parameters: {'n_estimators': 240, 'num_leaves': 63, 'max_depth': 7, 'learning_rate': 0.023166564805801423, 'subsample': 0.8686422415836177, 'colsample_bytree': 0.6507322601822999, 'reg_alpha': 0.4907072476894177, 'reg_lambda': 0.5520293666334543, 'min_child_samples': 50}.
# [I 2025-10-27 23:23:05,013] Trial 28 finished with values: [0.9195547510991501, 0.9726494189934815] and parameters: {'n_estimators': 276, 'num_leaves': 81, 'max_depth': 4, 'learning_rate': 0.04029146294695275, 'subsample': 0.7715306178572576, 'colsample_bytree': 0.7606345065083159, 'reg_alpha': 0.1989706599983438, 'reg_lambda': 0.7049211433340475, 'min_child_samples': 66}.
# [I 2025-10-27 23:23:06,557] Trial 29 finished with values: [0.9244237402568345, 0.9771951302677784] and parameters: {'n_estimators': 424, 'num_leaves': 27, 'max_depth': 8, 'learning_rate': 0.06786071551527241, 'subsample': 0.7032794554413349, 'colsample_bytree': 0.6715490596318728, 'reg_alpha': 0.09637299800859073, 'reg_lambda': 0.8398384561816132, 'min_child_samples': 58}.
# [I 2025-10-27 23:23:08,802] Trial 30 finished with values: [0.9238573125042343, 0.9770392116217272] and parameters: {'n_estimators': 487, 'num_leaves': 38, 'max_depth': 8, 'learning_rate': 0.05122922795716562, 'subsample': 0.7196337956065544, 'colsample_bytree': 0.7125895740681581, 'reg_alpha': 0.00347684017629199, 'reg_lambda': 0.6214959541170412, 'min_child_samples': 44}.
# [I 2025-10-27 23:23:10,476] Trial 31 finished with values: [0.9244626133171883, 0.9771504105795099] and parameters: {'n_estimators': 417, 'num_leaves': 25, 'max_depth': 8, 'learning_rate': 0.0666416754501077, 'subsample': 0.7820620606389328, 'colsample_bytree': 0.6722722644867055, 'reg_alpha': 0.10243930251087723, 'reg_lambda': 0.8521482557007038, 'min_child_samples': 56}.
# [I 2025-10-27 23:23:11,660] Trial 32 finished with values: [0.9247467934107704, 0.9770591922249503] and parameters: {'n_estimators': 228, 'num_leaves': 74, 'max_depth': 8, 'learning_rate': 0.06491476181041095, 'subsample': 0.7855332434753128, 'colsample_bytree': 0.6460525161507835, 'reg_alpha': 0.8891391195673126, 'reg_lambda': 0.5985866661816645, 'min_child_samples': 56}.
# [I 2025-10-27 23:23:13,063] Trial 33 finished with values: [0.9247802810066169, 0.9771109576298321] and parameters: {'n_estimators': 409, 'num_leaves': 20, 'max_depth': 8, 'learning_rate': 0.06881658443675089, 'subsample': 0.6947965860285096, 'colsample_bytree': 0.6723232442083896, 'reg_alpha': 0.08945715065496646, 'reg_lambda': 0.8127803301083263, 'min_child_samples': 57}.
# [I 2025-10-27 23:23:14,557] Trial 34 finished with values: [0.9247937590193008, 0.976958476321136] and parameters: {'n_estimators': 416, 'num_leaves': 22, 'max_depth': 6, 'learning_rate': 0.0794975180988785, 'subsample': 0.828712220997725, 'colsample_bytree': 0.9360680534349978, 'reg_alpha': 0.10163044821181778, 'reg_lambda': 0.8415852197972719, 'min_child_samples': 37}.
# [I 2025-10-27 23:23:16,036] Trial 35 finished with values: [0.9239730090537442, 0.9762099789972778] and parameters: {'n_estimators': 460, 'num_leaves': 58, 'max_depth': 5, 'learning_rate': 0.03427778850225635, 'subsample': 0.8783547221751052, 'colsample_bytree': 0.6708607194804788, 'reg_alpha': 0.43624444533936946, 'reg_lambda': 0.7876300871377178, 'min_child_samples': 56}.
# [I 2025-10-27 23:23:17,845] Trial 36 finished with values: [0.9239627662442734, 0.9771259941812541] and parameters: {'n_estimators': 352, 'num_leaves': 42, 'max_depth': 8, 'learning_rate': 0.06252894313041314, 'subsample': 0.6946687418250758, 'colsample_bytree': 0.7386821081085221, 'reg_alpha': 0.546284933111804, 'reg_lambda': 0.724479495756479, 'min_child_samples': 61}.
# [I 2025-10-27 23:23:19,245] Trial 37 finished with values: [0.9163285725426213, 0.9684864396561522] and parameters: {'n_estimators': 323, 'num_leaves': 72, 'max_depth': 7, 'learning_rate': 0.010463596946441998, 'subsample': 0.6513737700091045, 'colsample_bytree': 0.6773978673871632, 'reg_alpha': 0.3139939535616604, 'reg_lambda': 0.9818540631463814, 'min_child_samples': 23}.
# [I 2025-10-27 23:23:20,884] Trial 38 finished with values: [0.9237352834697132, 0.9769010747795931] and parameters: {'n_estimators': 383, 'num_leaves': 86, 'max_depth': 6, 'learning_rate': 0.09206432885498506, 'subsample': 0.7520712549724653, 'colsample_bytree': 0.6221077395771946, 'reg_alpha': 0.2169842191903832, 'reg_lambda': 0.43669654796318985, 'min_child_samples': 51}.
# [I 2025-10-27 23:23:21,434] Trial 39 finished with values: [0.9073994537269723, 0.9610484789091068] and parameters: {'n_estimators': 190, 'num_leaves': 93, 'max_depth': 4, 'learning_rate': 0.02475136675520029, 'subsample': 0.9553648575205256, 'colsample_bytree': 0.6395609626645856, 'reg_alpha': 0.12606807754417076, 'reg_lambda': 0.7865537555573795, 'min_child_samples': 77}.
# [I 2025-10-27 23:23:22,323] Trial 40 finished with values: [0.9227174098903458, 0.9759180665993012] and parameters: {'n_estimators': 406, 'num_leaves': 24, 'max_depth': 3, 'learning_rate': 0.07490283635466294, 'subsample': 0.6310438156456877, 'colsample_bytree': 0.7208687995949619, 'reg_alpha': 0.42489314171240217, 'reg_lambda': 0.9358883217422465, 'min_child_samples': 35}.
# [I 2025-10-27 23:23:23,987] Trial 41 finished with values: [0.9241084297419664, 0.9767734264568277] and parameters: {'n_estimators': 412, 'num_leaves': 29, 'max_depth': 6, 'learning_rate': 0.07622447452423775, 'subsample': 0.8224640264902072, 'colsample_bytree': 0.9417296184840578, 'reg_alpha': 0.07305068372537718, 'reg_lambda': 0.8421428762202536, 'min_child_samples': 61}.
# [I 2025-10-27 23:23:25,589] Trial 42 finished with values: [0.9245275407899829, 0.9766812190234441] and parameters: {'n_estimators': 294, 'num_leaves': 112, 'max_depth': 7, 'learning_rate': 0.044224953906647116, 'subsample': 0.8367936001094264, 'colsample_bytree': 0.8241145511968017, 'reg_alpha': 0.16421544884373906, 'reg_lambda': 0.8818121108619543, 'min_child_samples': 67}.
# [I 2025-10-27 23:23:27,480] Trial 43 finished with values: [0.9240700730494726, 0.9771466265152471] and parameters: {'n_estimators': 438, 'num_leaves': 57, 'max_depth': 6, 'learning_rate': 0.059707818130119474, 'subsample': 0.6907856157349802, 'colsample_bytree': 0.6256956281984972, 'reg_alpha': 0.0869228512011461, 'reg_lambda': 0.6873198574600132, 'min_child_samples': 35}.
# [I 2025-10-27 23:23:28,662] Trial 44 finished with values: [0.913806752774669, 0.9681019780189454] and parameters: {'n_estimators': 264, 'num_leaves': 21, 'max_depth': 8, 'learning_rate': 0.015612662630897731, 'subsample': 0.8994197559433014, 'colsample_bytree': 0.6743225479531161, 'reg_alpha': 0.3029172267592081, 'reg_lambda': 0.31465109534753327, 'min_child_samples': 48}.
# [I 2025-10-27 23:23:30,951] Trial 45 finished with values: [0.9230038503189331, 0.9762886090230433] and parameters: {'n_estimators': 386, 'num_leaves': 46, 'max_depth': 7, 'learning_rate': 0.1827674598137366, 'subsample': 0.8088017381166964, 'colsample_bytree': 0.6373424348601083, 'reg_alpha': 0.693807987053339, 'reg_lambda': 0.5302078950552739, 'min_child_samples': 54}.
# [I 2025-10-27 23:23:32,556] Trial 46 finished with values: [0.9237568195221497, 0.9770654336358979] and parameters: {'n_estimators': 342, 'num_leaves': 77, 'max_depth': 7, 'learning_rate': 0.08435584975732917, 'subsample': 0.7032729878757844, 'colsample_bytree': 0.6106032784274433, 'reg_alpha': 0.9018208213294038, 'reg_lambda': 0.5885074322433452, 'min_child_samples': 77}.
# [I 2025-10-27 23:23:33,982] Trial 47 finished with values: [0.9238453529771036, 0.9770841156627382] and parameters: {'n_estimators': 321, 'num_leaves': 32, 'max_depth': 8, 'learning_rate': 0.09944127301483019, 'subsample': 0.7375920087140528, 'colsample_bytree': 0.6854241896319018, 'reg_alpha': 0.39894665679744434, 'reg_lambda': 0.7694780782738799, 'min_child_samples': 60}.
# [I 2025-10-27 23:23:36,134] Trial 48 finished with values: [0.9251668648281767, 0.9772723369545412] and parameters: {'n_estimators': 476, 'num_leaves': 96, 'max_depth': 7, 'learning_rate': 0.03988713843767786, 'subsample': 0.7598192784850586, 'colsample_bytree': 0.6601261898491356, 'reg_alpha': 0.7867117567576061, 'reg_lambda': 0.8423778985542689, 'min_child_samples': 22}.
# [I 2025-10-27 23:23:37,257] Trial 49 finished with values: [0.9197959598445026, 0.973049124519879] and parameters: {'n_estimators': 466, 'num_leaves': 97, 'max_depth': 3, 'learning_rate': 0.03734278342361738, 'subsample': 0.7666038472752483, 'colsample_bytree': 0.9949029268075161, 'reg_alpha': 0.8247480368863458, 'reg_lambda': 0.9257127468909766, 'min_child_samples': 26}.
# [I 2025-10-27 23:23:38,879] Trial 50 finished with values: [0.9221511084943956, 0.9748960292341812] and parameters: {'n_estimators': 485, 'num_leaves': 107, 'max_depth': 5, 'learning_rate': 0.024532012332300273, 'subsample': 0.6722167794688764, 'colsample_bytree': 0.7590055391421855, 'reg_alpha': 0.7686914975190099, 'reg_lambda': 0.9971001597879736, 'min_child_samples': 19}.
# [I 2025-10-27 23:23:40,675] Trial 51 finished with values: [0.9217799781112062, 0.9746643107943672] and parameters: {'n_estimators': 475, 'num_leaves': 116, 'max_depth': 6, 'learning_rate': 0.019555314775360322, 'subsample': 0.7253431780986764, 'colsample_bytree': 0.6621737004723066, 'reg_alpha': 0.9466621400083237, 'reg_lambda': 0.8384221399414936, 'min_child_samples': 29}.
# [I 2025-10-27 23:23:42,637] Trial 52 finished with values: [0.9237966962105432, 0.9761825743661007] and parameters: {'n_estimators': 442, 'num_leaves': 87, 'max_depth': 6, 'learning_rate': 0.028472005060642958, 'subsample': 0.7060709587968735, 'colsample_bytree': 0.9615280601460168, 'reg_alpha': 0.5731918979040141, 'reg_lambda': 0.8947042481569796, 'min_child_samples': 14}.
# [I 2025-10-27 23:23:45,195] Trial 53 finished with values: [0.9246547311826377, 0.9772031175609056] and parameters: {'n_estimators': 458, 'num_leaves': 82, 'max_depth': 7, 'learning_rate': 0.04371377362283406, 'subsample': 0.7616932743423555, 'colsample_bytree': 0.9099212143665169, 'reg_alpha': 0.8612151011085645, 'reg_lambda': 0.811069617494374, 'min_child_samples': 22}.
# [I 2025-10-27 23:23:46,846] Trial 54 finished with values: [0.9238543208063129, 0.976756402672344] and parameters: {'n_estimators': 499, 'num_leaves': 98, 'max_depth': 7, 'learning_rate': 0.2239114089669257, 'subsample': 0.7595168857160628, 'colsample_bytree': 0.9048679736842785, 'reg_alpha': 0.8960788972840148, 'reg_lambda': 0.9512794939337432, 'min_child_samples': 10}.
# [I 2025-10-27 23:23:49,261] Trial 55 finished with values: [0.924896616813559, 0.9773363635065729] and parameters: {'n_estimators': 452, 'num_leaves': 104, 'max_depth': 7, 'learning_rate': 0.0471335146708202, 'subsample': 0.788745696286114, 'colsample_bytree': 0.648184271520837, 'reg_alpha': 0.9881573999677098, 'reg_lambda': 0.07662714232017731, 'min_child_samples': 23}.
# [I 2025-10-27 23:23:51,747] Trial 56 finished with values: [0.9249571979400426, 0.9774155591706002] and parameters: {'n_estimators': 452, 'num_leaves': 105, 'max_depth': 7, 'learning_rate': 0.04795057320228168, 'subsample': 0.7453929638791946, 'colsample_bytree': 0.7841784292008945, 'reg_alpha': 0.9671780302363777, 'reg_lambda': 0.24135621668808988, 'min_child_samples': 22}.
# [I 2025-10-27 23:23:54,137] Trial 57 finished with values: [0.9245674478891687, 0.9773447412648681] and parameters: {'n_estimators': 472, 'num_leaves': 102, 'max_depth': 7, 'learning_rate': 0.04712684457334177, 'subsample': 0.7357674891571253, 'colsample_bytree': 0.7867374659912695, 'reg_alpha': 0.9866975900896506, 'reg_lambda': 0.24469849666299526, 'min_child_samples': 31}.
# [I 2025-10-27 23:23:56,731] Trial 58 finished with values: [0.9246926575378481, 0.9772771811941613] and parameters: {'n_estimators': 475, 'num_leaves': 104, 'max_depth': 7, 'learning_rate': 0.04923889192328196, 'subsample': 0.738407264281155, 'colsample_bytree': 0.8543612332413743, 'reg_alpha': 0.9719426251068215, 'reg_lambda': 0.07063283056747532, 'min_child_samples': 31}.
# [I 2025-10-27 23:23:59,088] Trial 59 finished with values: [0.9247721983345313, 0.9772127857791334] and parameters: {'n_estimators': 476, 'num_leaves': 103, 'max_depth': 7, 'learning_rate': 0.036288167549285655, 'subsample': 0.7324081288756371, 'colsample_bytree': 0.793601554439522, 'reg_alpha': 0.9874086709252337, 'reg_lambda': 0.242484101520758, 'min_child_samples': 28}.
# [I 2025-10-27 23:24:01,241] Trial 60 finished with values: [0.9248879764255066, 0.9772200900083806] and parameters: {'n_estimators': 438, 'num_leaves': 116, 'max_depth': 7, 'learning_rate': 0.03778141688984632, 'subsample': 0.7981084151130197, 'colsample_bytree': 0.7886612085983874, 'reg_alpha': 0.7423468366071063, 'reg_lambda': 0.19902546581272418, 'min_child_samples': 18}.
# [I 2025-10-27 23:24:03,673] Trial 61 finished with values: [0.9244116215932081, 0.9772836438490153] and parameters: {'n_estimators': 446, 'num_leaves': 116, 'max_depth': 7, 'learning_rate': 0.04710085616644623, 'subsample': 0.7822911237254015, 'colsample_bytree': 0.8534845737971822, 'reg_alpha': 0.7478004409373318, 'reg_lambda': 0.16863398729390372, 'min_child_samples': 18}.
# [I 2025-10-27 23:24:05,994] Trial 62 finished with values: [0.9246933719593771, 0.9772827422003855] and parameters: {'n_estimators': 440, 'num_leaves': 116, 'max_depth': 7, 'learning_rate': 0.047269165361231685, 'subsample': 0.7825265488693883, 'colsample_bytree': 0.7794736074693959, 'reg_alpha': 0.753221037363885, 'reg_lambda': 0.20272670290169525, 'min_child_samples': 19}.
# [I 2025-10-27 23:24:08,395] Trial 63 finished with values: [0.9241217121738979, 0.9773081857916557] and parameters: {'n_estimators': 448, 'num_leaves': 109, 'max_depth': 7, 'learning_rate': 0.056856146608494564, 'subsample': 0.7495272772980943, 'colsample_bytree': 0.8158537655018065, 'reg_alpha': 0.8160487921220972, 'reg_lambda': 0.3162557277979747, 'min_child_samples': 25}.
# [I 2025-10-27 23:24:10,967] Trial 64 finished with values: [0.9245748231537113, 0.9772730117270877] and parameters: {'n_estimators': 485, 'num_leaves': 108, 'max_depth': 7, 'learning_rate': 0.05629811761223487, 'subsample': 0.7489048891657638, 'colsample_bytree': 0.8170252998861491, 'reg_alpha': 0.8009063499374626, 'reg_lambda': 0.2995206121292475, 'min_child_samples': 24}.
# [I 2025-10-27 23:24:13,350] Trial 65 finished with values: [0.9248158334280108, 0.9771915405744219] and parameters: {'n_estimators': 431, 'num_leaves': 67, 'max_depth': 7, 'learning_rate': 0.03900080701200214, 'subsample': 0.7173236836031864, 'colsample_bytree': 0.8856811986671762, 'reg_alpha': 0.8541939942793998, 'reg_lambda': 0.3552687803071476, 'min_child_samples': 14}.
# [I 2025-10-27 23:24:15,550] Trial 66 finished with values: [0.925321391614391, 0.9770590332940219] and parameters: {'n_estimators': 456, 'num_leaves': 89, 'max_depth': 7, 'learning_rate': 0.03017434335761406, 'subsample': 0.8030820394356228, 'colsample_bytree': 0.8120875857905225, 'reg_alpha': 0.9374610346617579, 'reg_lambda': 0.14961460151433437, 'min_child_samples': 22}.
# [I 2025-10-27 23:24:17,967] Trial 67 finished with values: [0.924468996243852, 0.9764058495265125] and parameters: {'n_estimators': 399, 'num_leaves': 96, 'max_depth': 7, 'learning_rate': 0.026713059603291206, 'subsample': 0.8027405432954243, 'colsample_bytree': 0.8379773164636733, 'reg_alpha': 0.9422668709161452, 'reg_lambda': 0.1484654262600172, 'min_child_samples': 21}.
# [I 2025-10-27 23:24:20,394] Trial 68 finished with values: [0.9234465731691951, 0.9759948027161222] and parameters: {'n_estimators': 458, 'num_leaves': 91, 'max_depth': 7, 'learning_rate': 0.021022627365450786, 'subsample': 0.8150317305145728, 'colsample_bytree': 0.805367224548646, 'reg_alpha': 0.9218809436356881, 'reg_lambda': 0.05938864102728342, 'min_child_samples': 31}.
# [I 2025-10-27 23:24:22,483] Trial 69 finished with values: [0.9249911552143616, 0.9766829869583235] and parameters: {'n_estimators': 466, 'num_leaves': 100, 'max_depth': 6, 'learning_rate': 0.030717941583254606, 'subsample': 0.8586710384779921, 'colsample_bytree': 0.7784258613599013, 'reg_alpha': 0.9990858298890221, 'reg_lambda': 0.25503486286500654, 'min_child_samples': 13}.
# [I 2025-10-27 23:24:24,083] Trial 70 finished with values: [0.9230521251304337, 0.9753723703992714] and parameters: {'n_estimators': 358, 'num_leaves': 100, 'max_depth': 6, 'learning_rate': 0.03150800254340991, 'subsample': 0.8383198707409112, 'colsample_bytree': 0.7797349225209405, 'reg_alpha': 0.9916412995742306, 'reg_lambda': 0.1190750385946971, 'min_child_samples': 94}.
# [I 2025-10-27 23:24:26,970] Trial 71 finished with values: [0.9215040517185445, 0.9745210810571573] and parameters: {'n_estimators': 433, 'num_leaves': 90, 'max_depth': 7, 'learning_rate': 0.016875389150796172, 'subsample': 0.8546689548304333, 'colsample_bytree': 0.7697330254195279, 'reg_alpha': 0.8643912784113823, 'reg_lambda': 0.22267220862137638, 'min_child_samples': 15}.
# [I 2025-10-27 23:24:28,946] Trial 72 finished with values: [0.9217574069549679, 0.9743793201217246] and parameters: {'n_estimators': 467, 'num_leaves': 78, 'max_depth': 4, 'learning_rate': 0.03022868591018835, 'subsample': 0.79507853201697, 'colsample_bytree': 0.8026233424187553, 'reg_alpha': 0.9607906404383736, 'reg_lambda': 0.2765536192918624, 'min_child_samples': 12}.
# [I 2025-10-27 23:24:31,941] Trial 73 finished with values: [0.9250250958578738, 0.9769007008820353] and parameters: {'n_estimators': 457, 'num_leaves': 106, 'max_depth': 7, 'learning_rate': 0.02737794113615552, 'subsample': 0.7938639821804903, 'colsample_bytree': 0.742517751317795, 'reg_alpha': 0.9275786028122773, 'reg_lambda': 0.19493384947952694, 'min_child_samples': 21}.
# [I 2025-10-27 23:24:35,050] Trial 74 finished with values: [0.9254567213083776, 0.97715107835324] and parameters: {'n_estimators': 425, 'num_leaves': 106, 'max_depth': 7, 'learning_rate': 0.035462623704975, 'subsample': 0.7765047664352467, 'colsample_bytree': 0.7532539281450102, 'reg_alpha': 0.9276120882678518, 'reg_lambda': 0.19606899899952202, 'min_child_samples': 18}.
# [I 2025-10-27 23:24:36,065] Trial 75 finished with values: [0.9183004560293924, 0.970954236354681] and parameters: {'n_estimators': 375, 'num_leaves': 113, 'max_depth': 3, 'learning_rate': 0.03469796408486642, 'subsample': 0.7692645794208258, 'colsample_bytree': 0.7493348732185294, 'reg_alpha': 0.9353187234372696, 'reg_lambda': 0.20440954099020908, 'min_child_samples': 17}.
# [I 2025-10-27 23:24:37,604] Trial 76 finished with values: [0.9243255744987448, 0.9770356894009927] and parameters: {'n_estimators': 393, 'num_leaves': 106, 'max_depth': 5, 'learning_rate': 0.14318260576239306, 'subsample': 0.7762904657783893, 'colsample_bytree': 0.7385898899212523, 'reg_alpha': 0.9188896816209011, 'reg_lambda': 0.1415970071009062, 'min_child_samples': 21}.
# [I 2025-10-27 23:24:39,030] Trial 77 finished with values: [0.9233409447788125, 0.9766310413793736] and parameters: {'n_estimators': 306, 'num_leaves': 110, 'max_depth': 7, 'learning_rate': 0.27854674914114635, 'subsample': 0.9774539589275157, 'colsample_bytree': 0.7507457066670341, 'reg_alpha': 0.8832116071204312, 'reg_lambda': 0.3471324470664966, 'min_child_samples': 25}.
# [I 2025-10-27 23:24:39,856] Trial 78 finished with values: [0.9085368073701193, 0.9641170544188005] and parameters: {'n_estimators': 169, 'num_leaves': 104, 'max_depth': 8, 'learning_rate': 0.014369551637916795, 'subsample': 0.9397601109522167, 'colsample_bytree': 0.7272500735079462, 'reg_alpha': 0.8345580294775458, 'reg_lambda': 0.17421514526905854, 'min_child_samples': 85}.
# [I 2025-10-27 23:24:40,983] Trial 79 finished with values: [0.9218193463220409, 0.9745178264615317] and parameters: {'n_estimators': 369, 'num_leaves': 120, 'max_depth': 4, 'learning_rate': 0.03855393762417159, 'subsample': 0.6611800780116361, 'colsample_bytree': 0.7072302375048504, 'reg_alpha': 0.9625449254735342, 'reg_lambda': 0.39836588261608685, 'min_child_samples': 10}.
# [I 2025-10-27 23:24:42,543] Trial 80 finished with values: [0.9169258995100691, 0.9697034505310795] and parameters: {'n_estimators': 339, 'num_leaves': 114, 'max_depth': 7, 'learning_rate': 0.012125132244371561, 'subsample': 0.7955435536703347, 'colsample_bytree': 0.7410409519483391, 'reg_alpha': 0.7866526792784186, 'reg_lambda': 0.28326865463323336, 'min_child_samples': 16}.
# [I 2025-10-27 23:24:44,693] Trial 81 finished with values: [0.9243435804154737, 0.9773263186123393] and parameters: {'n_estimators': 452, 'num_leaves': 108, 'max_depth': 7, 'learning_rate': 0.05414626908341972, 'subsample': 0.7550372968114588, 'colsample_bytree': 0.7680173843470506, 'reg_alpha': 0.9143615614978411, 'reg_lambda': 0.18151094614285895, 'min_child_samples': 27}.
# [I 2025-10-27 23:24:46,046] Trial 82 finished with values: [0.9236703771520914, 0.9760036233977022] and parameters: {'n_estimators': 282, 'num_leaves': 102, 'max_depth': 7, 'learning_rate': 0.033342475665245785, 'subsample': 0.6297578854364582, 'colsample_bytree': 0.7911691832919369, 'reg_alpha': 0.9027819581191822, 'reg_lambda': 0.19746746116359856, 'min_child_samples': 20}.
# [I 2025-10-27 23:24:48,174] Trial 83 finished with values: [0.9254966579248705, 0.9771845642309861] and parameters: {'n_estimators': 352, 'num_leaves': 106, 'max_depth': 7, 'learning_rate': 0.04384383144500199, 'subsample': 0.7578985992393129, 'colsample_bytree': 0.7703297075098392, 'reg_alpha': 0.9218233746891704, 'reg_lambda': 0.10230323769925295, 'min_child_samples': 18}.
# [I 2025-10-27 23:24:48,975] Trial 84 finished with values: [0.9141766869660009, 0.9679136566868022] and parameters: {'n_estimators': 231, 'num_leaves': 111, 'max_depth': 3, 'learning_rate': 0.04091788764565832, 'subsample': 0.7545346352484171, 'colsample_bytree': 0.8033177071845496, 'reg_alpha': 0.8440915447203173, 'reg_lambda': 0.04191300239898514, 'min_child_samples': 81}.
# [I 2025-10-27 23:24:50,471] Trial 85 finished with values: [0.924970949759227, 0.9766874101374191] and parameters: {'n_estimators': 314, 'num_leaves': 109, 'max_depth': 6, 'learning_rate': 0.043636250666251736, 'subsample': 0.7414793941220352, 'colsample_bytree': 0.7603331026566061, 'reg_alpha': 0.8820764568914058, 'reg_lambda': 0.09669823172034875, 'min_child_samples': 27}.
# [I 2025-10-27 23:24:52,731] Trial 86 finished with values: [0.9245494761600429, 0.9773516030711598] and parameters: {'n_estimators': 287, 'num_leaves': 95, 'max_depth': 8, 'learning_rate': 0.049169538003898144, 'subsample': 0.7242863576459416, 'colsample_bytree': 0.7672084138873067, 'reg_alpha': 0.4908258632070321, 'reg_lambda': 0.0023934023777085617, 'min_child_samples': 17}.
# [I 2025-10-27 23:24:53,513] Trial 87 finished with values: [0.9221466516498907, 0.9748434674825722] and parameters: {'n_estimators': 205, 'num_leaves': 93, 'max_depth': 5, 'learning_rate': 0.05490816347978794, 'subsample': 0.7293317655549689, 'colsample_bytree': 0.8391976748588763, 'reg_alpha': 0.6131480010277485, 'reg_lambda': 0.002348067080042371, 'min_child_samples': 38}.
# [I 2025-10-27 23:24:55,391] Trial 88 finished with values: [0.9238276242650175, 0.9767543568440274] and parameters: {'n_estimators': 351, 'num_leaves': 96, 'max_depth': 8, 'learning_rate': 0.05159013205525826, 'subsample': 0.7084979864697063, 'colsample_bytree': 0.7717493935981388, 'reg_alpha': 0.9606659333428581, 'reg_lambda': 0.0312044572574538, 'min_child_samples': 95}.
# [I 2025-10-27 23:24:56,621] Trial 89 finished with values: [0.924031736679265, 0.9759264785363282] and parameters: {'n_estimators': 290, 'num_leaves': 50, 'max_depth': 6, 'learning_rate': 0.04622127979448727, 'subsample': 0.6851399003204214, 'colsample_bytree': 0.7312740440361395, 'reg_alpha': 0.6754443395503651, 'reg_lambda': 0.10250637949451538, 'min_child_samples': 100}.
# [I 2025-10-27 23:24:58,227] Trial 90 finished with values: [0.924467169403404, 0.9768685663213814] and parameters: {'n_estimators': 270, 'num_leaves': 99, 'max_depth': 8, 'learning_rate': 0.042735452986878655, 'subsample': 0.6037518352564165, 'colsample_bytree': 0.8122096940994828, 'reg_alpha': 0.9149948166130695, 'reg_lambda': 0.07724092196711478, 'min_child_samples': 44}.
# [I 2025-10-27 23:24:59,552] Trial 91 finished with values: [0.9230809007338724, 0.976824926279611] and parameters: {'n_estimators': 422, 'num_leaves': 104, 'max_depth': 6, 'learning_rate': 0.19880146768338405, 'subsample': 0.7620734589723923, 'colsample_bytree': 0.7845389211376917, 'reg_alpha': 0.8756381057580694, 'reg_lambda': 0.12363985038342223, 'min_child_samples': 23}.
# [I 2025-10-27 23:25:00,702] Trial 92 finished with values: [0.9246207409589102, 0.9768905656818737] and parameters: {'n_estimators': 327, 'num_leaves': 102, 'max_depth': 5, 'learning_rate': 0.060547693979540324, 'subsample': 0.7758675982012797, 'colsample_bytree': 0.7647493750428269, 'reg_alpha': 0.4662846263902459, 'reg_lambda': 0.1385352930537227, 'min_child_samples': 17}.
# [I 2025-10-27 23:25:02,962] Trial 93 finished with values: [0.9249581533857244, 0.977327065492501] and parameters: {'n_estimators': 398, 'num_leaves': 107, 'max_depth': 8, 'learning_rate': 0.0357218378802482, 'subsample': 0.9099609356296885, 'colsample_bytree': 0.7548938678401447, 'reg_alpha': 0.9754744677255623, 'reg_lambda': 0.038647722111428806, 'min_child_samples': 31}.
# [I 2025-10-27 23:25:04,910] Trial 94 finished with values: [0.9230556851472956, 0.9759036556480356] and parameters: {'n_estimators': 373, 'num_leaves': 57, 'max_depth': 8, 'learning_rate': 0.11055472002174208, 'subsample': 0.7214152697508375, 'colsample_bytree': 0.7542215052485481, 'reg_alpha': 0.351659018531218, 'reg_lambda': 0.08467368214575266, 'min_child_samples': 12}.
# [I 2025-10-27 23:25:05,759] Trial 95 finished with values: [0.9226921221864051, 0.9751804837242796] and parameters: {'n_estimators': 317, 'num_leaves': 44, 'max_depth': 4, 'learning_rate': 0.05040021514605237, 'subsample': 0.9078541526959306, 'colsample_bytree': 0.79718913486348, 'reg_alpha': 0.971795675738531, 'reg_lambda': 0.031955443414776824, 'min_child_samples': 31}.
# [I 2025-10-27 23:25:07,328] Trial 96 finished with values: [0.9252709703896275, 0.976673530017956] and parameters: {'n_estimators': 361, 'num_leaves': 52, 'max_depth': 6, 'learning_rate': 0.0355091584747689, 'subsample': 0.7408079305516052, 'colsample_bytree': 0.7725332661940713, 'reg_alpha': 0.5295332385532301, 'reg_lambda': 0.050314496612497255, 'min_child_samples': 16}.
# [I 2025-10-27 23:25:08,952] Trial 97 finished with values: [0.923679981522624, 0.9766404688559164] and parameters: {'n_estimators': 346, 'num_leaves': 38, 'max_depth': 8, 'learning_rate': 0.07096357970796319, 'subsample': 0.8845287461739775, 'colsample_bytree': 0.9755554530237787, 'reg_alpha': 0.25784048118455716, 'reg_lambda': 0.10793627542180269, 'min_child_samples': 74}.
# [I 2025-10-27 23:25:09,746] Trial 98 finished with values: [0.9185248059484538, 0.9716451470337603] and parameters: {'n_estimators': 337, 'num_leaves': 107, 'max_depth': 3, 'learning_rate': 0.04185924471857822, 'subsample': 0.7577152210713267, 'colsample_bytree': 0.9352215173238854, 'reg_alpha': 0.940428838129275, 'reg_lambda': 0.14737066768553023, 'min_child_samples': 23}.
# [I 2025-10-27 23:25:10,832] Trial 99 finished with values: [0.9243988882036213, 0.9762783152961543] and parameters: {'n_estimators': 331, 'num_leaves': 34, 'max_depth': 5, 'learning_rate': 0.054346491986031094, 'subsample': 0.7330352659013428, 'colsample_bytree': 0.7311227307686671, 'reg_alpha': 0.9023569261279233, 'reg_lambda': 0.453962506616662, 'min_child_samples': 80}.
# [I 2025-10-27 23:25:12,536] Trial 100 finished with values: [0.9223114631049837, 0.9755421203525861] and parameters: {'n_estimators': 390, 'num_leaves': 114, 'max_depth': 6, 'learning_rate': 0.16444912614048543, 'subsample': 0.7477278814165478, 'colsample_bytree': 0.7184820254172691, 'reg_alpha': 0.048246611421399965, 'reg_lambda': 0.16677852119957526, 'min_child_samples': 68}.
# [I 2025-10-27 23:25:14,751] Trial 101 finished with values: [0.9242335147462731, 0.9774283100079072] and parameters: {'n_estimators': 401, 'num_leaves': 105, 'max_depth': 8, 'learning_rate': 0.0465498412206853, 'subsample': 0.769157582031927, 'colsample_bytree': 0.7878175675219439, 'reg_alpha': 0.982703844633441, 'reg_lambda': 0.022223433010300622, 'min_child_samples': 18}.
# [I 2025-10-27 23:25:16,903] Trial 102 finished with values: [0.9236280458346856, 0.9768424011733191] and parameters: {'n_estimators': 401, 'num_leaves': 95, 'max_depth': 8, 'learning_rate': 0.047494431736110315, 'subsample': 0.9367994183050588, 'colsample_bytree': 0.7665194660630056, 'reg_alpha': 0.721565755119536, 'reg_lambda': 0.08610510807314811, 'min_child_samples': 89}.
# [I 2025-10-27 23:25:17,962] Trial 103 finished with values: [0.9233219457076424, 0.9766644882997818] and parameters: {'n_estimators': 362, 'num_leaves': 74, 'max_depth': 8, 'learning_rate': 0.2618335547495837, 'subsample': 0.9976520843326311, 'colsample_bytree': 0.755757979090435, 'reg_alpha': 0.8568970692142638, 'reg_lambda': 0.016396517378311895, 'min_child_samples': 19}.
# [I 2025-10-27 23:25:19,282] Trial 104 finished with values: [0.9120795606314348, 0.9652547794268496] and parameters: {'n_estimators': 301, 'num_leaves': 54, 'max_depth': 6, 'learning_rate': 0.012436013231060729, 'subsample': 0.7859282175684745, 'colsample_bytree': 0.9555477347453907, 'reg_alpha': 0.9751968099090879, 'reg_lambda': 0.05442619808024157, 'min_child_samples': 14}.
# [I 2025-10-27 23:25:20,084] Trial 105 finished with values: [0.9193865660698989, 0.9721737334506096] and parameters: {'n_estimators': 250, 'num_leaves': 62, 'max_depth': 4, 'learning_rate': 0.04073244960366367, 'subsample': 0.7712353034544306, 'colsample_bytree': 0.8671695553071509, 'reg_alpha': 0.2978063438469067, 'reg_lambda': 0.07169974062270966, 'min_child_samples': 20}.
# [I 2025-10-27 23:25:21,079] Trial 106 finished with values: [0.9231913907489563, 0.9755398292865717] and parameters: {'n_estimators': 287, 'num_leaves': 105, 'max_depth': 5, 'learning_rate': 0.044868125319426105, 'subsample': 0.9792143283227127, 'colsample_bytree': 0.7826020518154309, 'reg_alpha': 0.7948241563314836, 'reg_lambda': 0.12354942924684452, 'min_child_samples': 64}.
# [I 2025-10-27 23:25:23,230] Trial 107 finished with values: [0.9229414521128927, 0.9758227565684195] and parameters: {'n_estimators': 381, 'num_leaves': 118, 'max_depth': 8, 'learning_rate': 0.13641753251805663, 'subsample': 0.6365918056999332, 'colsample_bytree': 0.6970091111222999, 'reg_alpha': 0.2084607920851863, 'reg_lambda': 0.5187538662483163, 'min_child_samples': 74}.
# [I 2025-10-27 23:25:24,015] Trial 108 finished with values: [0.9178140743354586, 0.9707930430609019] and parameters: {'n_estimators': 344, 'num_leaves': 111, 'max_depth': 3, 'learning_rate': 0.03689476335058722, 'subsample': 0.7123518363050593, 'colsample_bytree': 0.8238311536082403, 'reg_alpha': 0.9433677142656095, 'reg_lambda': 0.16308628010696868, 'min_child_samples': 12}.
# [I 2025-10-27 23:25:25,479] Trial 109 finished with values: [0.9233911374112184, 0.9759258377189867] and parameters: {'n_estimators': 354, 'num_leaves': 101, 'max_depth': 6, 'learning_rate': 0.033162661885158436, 'subsample': 0.9536114745264128, 'colsample_bytree': 0.9224173488208682, 'reg_alpha': 0.9125740939090332, 'reg_lambda': 0.486761943534625, 'min_child_samples': 29}.
# [I 2025-10-27 23:25:26,633] Trial 110 finished with values: [0.9241556053199877, 0.9767226638238041] and parameters: {'n_estimators': 405, 'num_leaves': 108, 'max_depth': 4, 'learning_rate': 0.15981230840054989, 'subsample': 0.7662859083365712, 'colsample_bytree': 0.7741313843853642, 'reg_alpha': 0.8282194857173967, 'reg_lambda': 0.4086314808642907, 'min_child_samples': 84}.
# [I 2025-10-27 23:25:27,435] Trial 111 finished with values: [0.9189178450779929, 0.9719194861700847] and parameters: {'n_estimators': 197, 'num_leaves': 70, 'max_depth': 5, 'learning_rate': 0.039735295750989795, 'subsample': 0.7553976951727046, 'colsample_bytree': 0.7891612113935645, 'reg_alpha': 0.3871475827937932, 'reg_lambda': 0.7550850145186028, 'min_child_samples': 17}.
# [I 2025-10-27 23:25:28,766] Trial 112 finished with values: [0.9247226947706118, 0.9766723484954194] and parameters: {'n_estimators': 224, 'num_leaves': 60, 'max_depth': 7, 'learning_rate': 0.0527656434926633, 'subsample': 0.802566525915819, 'colsample_bytree': 0.7483036762427407, 'reg_alpha': 0.8832130600132235, 'reg_lambda': 0.5616976940919144, 'min_child_samples': 18}.
# [I 2025-10-27 23:25:30,275] Trial 113 finished with values: [0.9231728515231182, 0.9767929726215135] and parameters: {'n_estimators': 310, 'num_leaves': 66, 'max_depth': 8, 'learning_rate': 0.20698241901342743, 'subsample': 0.7448334416785901, 'colsample_bytree': 0.7917697514171356, 'reg_alpha': 0.9280202502462798, 'reg_lambda': 0.6345694162809296, 'min_child_samples': 15}.
# [I 2025-10-27 23:25:31,321] Trial 114 finished with values: [0.9220585220358958, 0.9752345709109819] and parameters: {'n_estimators': 168, 'num_leaves': 98, 'max_depth': 7, 'learning_rate': 0.04913636915190319, 'subsample': 0.7760020178805238, 'colsample_bytree': 0.8986001483417869, 'reg_alpha': 0.5784084262692293, 'reg_lambda': 0.11104776506022766, 'min_child_samples': 25}.
# [I 2025-10-27 23:25:33,211] Trial 115 finished with values: [0.9235469432192858, 0.9770679274139535] and parameters: {'n_estimators': 379, 'num_leaves': 34, 'max_depth': 8, 'learning_rate': 0.10185118397312572, 'subsample': 0.7874255920664023, 'colsample_bytree': 0.7610672798560357, 'reg_alpha': 0.6291369667695098, 'reg_lambda': 0.1328229537650605, 'min_child_samples': 22}.
# [I 2025-10-27 23:25:34,878] Trial 116 finished with values: [0.9169029982009489, 0.9707763568931672] and parameters: {'n_estimators': 300, 'num_leaves': 41, 'max_depth': 7, 'learning_rate': 0.017985834292710497, 'subsample': 0.8713768299561545, 'colsample_bytree': 0.8778189562253204, 'reg_alpha': 0.999950441945871, 'reg_lambda': 0.023032150771133242, 'min_child_samples': 42}.
# [I 2025-10-27 23:25:36,606] Trial 117 finished with values: [0.9227538752635588, 0.9760449404230438] and parameters: {'n_estimators': 367, 'num_leaves': 106, 'max_depth': 6, 'learning_rate': 0.122667120044976, 'subsample': 0.7263895314177543, 'colsample_bytree': 0.8110574366522469, 'reg_alpha': 0.02121225842056068, 'reg_lambda': 0.060598709319446234, 'min_child_samples': 54}.
# [I 2025-10-27 23:25:38,619] Trial 118 finished with values: [0.9232374420656839, 0.9753619248641949] and parameters: {'n_estimators': 394, 'num_leaves': 87, 'max_depth': 7, 'learning_rate': 0.02271305095142718, 'subsample': 0.9130292174007535, 'colsample_bytree': 0.9879623388555212, 'reg_alpha': 0.8417537366223161, 'reg_lambda': 0.1027592435964935, 'min_child_samples': 48}.
# [I 2025-10-27 23:25:39,693] Trial 119 finished with values: [0.924386557817415, 0.9768585809373564] and parameters: {'n_estimators': 323, 'num_leaves': 112, 'max_depth': 5, 'learning_rate': 0.06316037225442016, 'subsample': 0.6652498412731187, 'colsample_bytree': 0.7769869550836279, 'reg_alpha': 0.5159321479043968, 'reg_lambda': 0.18856726881146413, 'min_child_samples': 10}.
# [I 2025-10-27 23:25:40,970] Trial 120 finished with values: [0.9243730776420066, 0.9765069663931408] and parameters: {'n_estimators': 331, 'num_leaves': 103, 'max_depth': 6, 'learning_rate': 0.038451647629239326, 'subsample': 0.7651881722594356, 'colsample_bytree': 0.6076786744304412, 'reg_alpha': 0.3351921007690519, 'reg_lambda': 0.23436112117622865, 'min_child_samples': 18}.
# [I 2025-10-27 23:25:42,106] Trial 121 finished with values: [0.9243646220624093, 0.9766997872288888] and parameters: {'n_estimators': 182, 'num_leaves': 115, 'max_depth': 8, 'learning_rate': 0.04869587272231287, 'subsample': 0.753786302957588, 'colsample_bytree': 0.7839286779638017, 'reg_alpha': 0.2814933168283885, 'reg_lambda': 0.08189588288808164, 'min_child_samples': 19}.
# [I 2025-10-27 23:25:42,923] Trial 122 finished with values: [0.9193573061634309, 0.9735152381428184] and parameters: {'n_estimators': 157, 'num_leaves': 118, 'max_depth': 7, 'learning_rate': 0.04494539125842301, 'subsample': 0.7812394364173273, 'colsample_bytree': 0.7659993975619702, 'reg_alpha': 0.1293519459580037, 'reg_lambda': 0.1507272234669254, 'min_child_samples': 87}.
# [I 2025-10-27 23:25:44,056] Trial 123 finished with values: [0.9234743635049999, 0.9760256132785795] and parameters: {'n_estimators': 413, 'num_leaves': 109, 'max_depth': 4, 'learning_rate': 0.057547192321475, 'subsample': 0.7357877971231415, 'colsample_bytree': 0.7981533274753598, 'reg_alpha': 0.4793665864693251, 'reg_lambda': 0.6028116141234924, 'min_child_samples': 92}.
# [I 2025-10-27 23:25:44,733] Trial 124 finished with values: [0.9006753957303372, 0.9530419041884098] and parameters: {'n_estimators': 275, 'num_leaves': 105, 'max_depth': 3, 'learning_rate': 0.011479965529936409, 'subsample': 0.6765412613993578, 'colsample_bytree': 0.8441070875820622, 'reg_alpha': 0.7567625704785477, 'reg_lambda': 0.6820708391171283, 'min_child_samples': 15}.
# [I 2025-10-27 23:25:47,085] Trial 125 finished with values: [0.9250593685554195, 0.9773061522804687] and parameters: {'n_estimators': 385, 'num_leaves': 110, 'max_depth': 7, 'learning_rate': 0.04633363164023162, 'subsample': 0.8985595646717807, 'colsample_bytree': 0.7455919968478563, 'reg_alpha': 0.9490963661918103, 'reg_lambda': 0.22011835428968862, 'min_child_samples': 21}.
# [I 2025-10-27 23:25:48,746] Trial 126 finished with values: [0.925348439580604, 0.9769977051210607] and parameters: {'n_estimators': 365, 'num_leaves': 48, 'max_depth': 7, 'learning_rate': 0.03599093514742281, 'subsample': 0.616379929983078, 'colsample_bytree': 0.7468798972958163, 'reg_alpha': 0.4210319361519777, 'reg_lambda': 0.8647795250428547, 'min_child_samples': 21}.
# ...
# [I 2025-10-27 23:42:01,739] Trial 156 finished with values: [0.9244558629221687, 0.9730825979635204] and parameters: {'max_features': 'sqrt', 'n_estimators': 427, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:05,216] Trial 157 finished with values: [0.9240724695651726, 0.9731416354723518] and parameters: {'max_features': 'sqrt', 'n_estimators': 462, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:08,703] Trial 158 finished with values: [0.9240102260411157, 0.9731431281602108] and parameters: {'max_features': 'sqrt', 'n_estimators': 464, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:11,842] Trial 159 finished with values: [0.9233246877486523, 0.9728354472791404] and parameters: {'max_features': 'sqrt', 'n_estimators': 433, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 2, 'bootstrap': False}.
# [I 2025-10-27 23:42:15,365] Trial 160 finished with values: [0.923392576355865, 0.973386829770349] and parameters: {'max_features': 'sqrt', 'n_estimators': 465, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 2, 'bootstrap': False}.
# [I 2025-10-27 23:42:18,717] Trial 161 finished with values: [0.9226695540201991, 0.9718173688873141] and parameters: {'max_features': 'sqrt', 'n_estimators': 459, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:42:22,272] Trial 162 finished with values: [0.9238211649953952, 0.9720884410078062] and parameters: {'max_features': 'sqrt', 'n_estimators': 465, 'max_depth': None, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:25,673] Trial 163 finished with values: [0.9239721042477754, 0.9731426914493456] and parameters: {'max_features': 'sqrt', 'n_estimators': 451, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:30,968] Trial 164 finished with values: [0.920752404200098, 0.9712660803606901] and parameters: {'max_features': None, 'n_estimators': 471, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:42:33,764] Trial 165 finished with values: [0.9145614789941439, 0.9657829700219981] and parameters: {'max_features': 'log2', 'n_estimators': 451, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:37,092] Trial 166 finished with values: [0.9241775283740341, 0.9729877181728123] and parameters: {'max_features': 'sqrt', 'n_estimators': 441, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:40,410] Trial 167 finished with values: [0.9241442531329834, 0.9729851389403996] and parameters: {'max_features': 'sqrt', 'n_estimators': 439, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:43,840] Trial 168 finished with values: [0.922677890689939, 0.9719498075693513] and parameters: {'max_features': 'sqrt', 'n_estimators': 464, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:42:50,958] Trial 169 finished with values: [0.9111914391188619, 0.9561687747440306] and parameters: {'max_features': None, 'n_estimators': 458, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:54,360] Trial 170 finished with values: [0.9240343281293012, 0.9731522678085406] and parameters: {'max_features': 'sqrt', 'n_estimators': 445, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:42:57,734] Trial 171 finished with values: [0.9240009613830233, 0.973147897913336] and parameters: {'max_features': 'sqrt', 'n_estimators': 444, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:01,221] Trial 172 finished with values: [0.9246378270779211, 0.973080377116147] and parameters: {'max_features': 'sqrt', 'n_estimators': 453, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:04,831] Trial 173 finished with values: [0.9245659186344705, 0.973082817749292] and parameters: {'max_features': 'sqrt', 'n_estimators': 475, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:08,421] Trial 174 finished with values: [0.9240273029300976, 0.972073211064131] and parameters: {'max_features': 'sqrt', 'n_estimators': 474, 'max_depth': None, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:11,808] Trial 175 finished with values: [0.9225683651005072, 0.9719267949277732] and parameters: {'max_features': 'sqrt', 'n_estimators': 449, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:43:14,960] Trial 176 finished with values: [0.9226525131312323, 0.9722373990140377] and parameters: {'max_features': 'log2', 'n_estimators': 455, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:17,830] Trial 177 finished with values: [0.9145842608748168, 0.9657419872964087] and parameters: {'max_features': 'sqrt', 'n_estimators': 465, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:23,607] Trial 178 finished with values: [0.9218452134866756, 0.9715361285252507] and parameters: {'max_features': None, 'n_estimators': 473, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:43:27,099] Trial 179 finished with values: [0.9246327517279922, 0.9730854642192183] and parameters: {'max_features': 'sqrt', 'n_estimators': 459, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:30,477] Trial 180 finished with values: [0.9241766291076262, 0.9723071529815206] and parameters: {'max_features': 'sqrt', 'n_estimators': 445, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:32,670] Trial 181 finished with values: [0.9240963553244574, 0.9729608573669383] and parameters: {'max_features': 'log2', 'n_estimators': 281, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:36,353] Trial 182 finished with values: [0.9240339746386023, 0.9731372599194904] and parameters: {'max_features': 'sqrt', 'n_estimators': 480, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:39,821] Trial 183 finished with values: [0.9225158835743371, 0.9719329613542135] and parameters: {'max_features': 'sqrt', 'n_estimators': 463, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:43:41,578] Trial 184 finished with values: [0.9238527114142953, 0.9728580851869628] and parameters: {'max_features': 'sqrt', 'n_estimators': 228, 'max_depth': 20, 'min_samples_split': 14, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:48,791] Trial 185 finished with values: [0.9112965933231014, 0.958597144772899] and parameters: {'max_features': None, 'n_estimators': 477, 'max_depth': None, 'min_samples_split': 12, 'min_samples_leaf': 2, 'bootstrap': False}.
# [I 2025-10-27 23:43:51,287] Trial 186 finished with values: [0.924000462480965, 0.9729601898920158] and parameters: {'max_features': 'sqrt', 'n_estimators': 328, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:43:54,608] Trial 187 finished with values: [0.9209242620558094, 0.971185524783639] and parameters: {'max_features': 'sqrt', 'n_estimators': 455, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:43:58,119] Trial 188 finished with values: [0.9240823895433609, 0.9729769931135962] and parameters: {'max_features': 'log2', 'n_estimators': 469, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:01,139] Trial 189 finished with values: [0.9146946685646947, 0.9658231327799993] and parameters: {'max_features': 'sqrt', 'n_estimators': 481, 'max_depth': 10, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:05,184] Trial 190 finished with values: [0.9121455877123185, 0.9573719592547603] and parameters: {'max_features': None, 'n_estimators': 263, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:08,587] Trial 191 finished with values: [0.9246377892164674, 0.9730818092711339] and parameters: {'max_features': 'sqrt', 'n_estimators': 452, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:11,832] Trial 192 finished with values: [0.9096283391227371, 0.965599549573215] and parameters: {'max_features': 'sqrt', 'n_estimators': 459, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 9, 'bootstrap': True}.
# [I 2025-10-27 23:44:15,209] Trial 193 finished with values: [0.9240916061630187, 0.9729841127619414] and parameters: {'max_features': 'sqrt', 'n_estimators': 447, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:18,776] Trial 194 finished with values: [0.9240715154833462, 0.9722886125038052] and parameters: {'max_features': 'sqrt', 'n_estimators': 467, 'max_depth': 25, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:21,516] Trial 195 finished with values: [0.9236628146052377, 0.9723089839833462] and parameters: {'max_features': 'log2', 'n_estimators': 357, 'max_depth': None, 'min_samples_split': 14, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:24,876] Trial 196 finished with values: [0.9208479444555238, 0.9715628393458956] and parameters: {'max_features': 'sqrt', 'n_estimators': 452, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 2, 'bootstrap': True}.
# [I 2025-10-27 23:44:31,204] Trial 197 finished with values: [0.9144860433442484, 0.9579577722936983] and parameters: {'max_features': None, 'n_estimators': 438, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:34,950] Trial 198 finished with values: [0.9240099504405604, 0.9731385589081811] and parameters: {'max_features': 'sqrt', 'n_estimators': 489, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:36,828] Trial 199 finished with values: [0.9146033303942275, 0.9657654108031477] and parameters: {'max_features': 'sqrt', 'n_estimators': 297, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:40,348] Trial 200 finished with values: [0.9214482037946613, 0.9711206490804712] and parameters: {'max_features': 'log2', 'n_estimators': 477, 'max_depth': 20, 'min_samples_split': 20, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:44:44,049] Trial 201 finished with values: [0.9245373495568724, 0.9730783389224819] and parameters: {'max_features': 'sqrt', 'n_estimators': 486, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:47,244] Trial 202 finished with values: [0.9221694886699505, 0.9724676592527975] and parameters: {'max_features': 'sqrt', 'n_estimators': 462, 'max_depth': 20, 'min_samples_split': 18, 'min_samples_leaf': 2, 'bootstrap': False}.
# [I 2025-10-27 23:44:50,031] Trial 203 finished with values: [0.9239221672173473, 0.972273590680821] and parameters: {'max_features': 'log2', 'n_estimators': 368, 'max_depth': 25, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:44:53,605] Trial 204 finished with values: [0.9078621004733766, 0.9621631658607126] and parameters: {'max_features': None, 'n_estimators': 246, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 10, 'bootstrap': False}.
# [I 2025-10-27 23:44:57,207] Trial 205 finished with values: [0.9224877126222907, 0.9715068169487765] and parameters: {'max_features': 'sqrt', 'n_estimators': 468, 'max_depth': None, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:44:59,278] Trial 206 finished with values: [0.9150212042344257, 0.9680321620766698] and parameters: {'max_features': 'sqrt', 'n_estimators': 314, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 9, 'bootstrap': False}.
# [I 2025-10-27 23:45:02,423] Trial 207 finished with values: [0.9215766996563642, 0.9717049579656752] and parameters: {'max_features': 'sqrt', 'n_estimators': 458, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 2, 'bootstrap': False}.
# [I 2025-10-27 23:45:05,537] Trial 208 finished with values: [0.9148345767103963, 0.9657863189771442] and parameters: {'max_features': 'sqrt', 'n_estimators': 490, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:45:08,849] Trial 209 finished with values: [0.9224951563270686, 0.971574340844068] and parameters: {'max_features': 'log2', 'n_estimators': 444, 'max_depth': 20, 'min_samples_split': 16, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:45:16,162] Trial 210 finished with values: [0.9120881745632685, 0.9573728027053873] and parameters: {'max_features': None, 'n_estimators': 471, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:45:18,957] Trial 211 finished with values: [0.924039311498312, 0.9731303563716223] and parameters: {'max_features': 'sqrt', 'n_estimators': 349, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:45:22,316] Trial 212 finished with values: [0.9157337614582226, 0.9687195067052586] and parameters: {'max_features': 'sqrt', 'n_estimators': 481, 'max_depth': 20, 'min_samples_split': 17, 'min_samples_leaf': 8, 'bootstrap': False}.
# [I 2025-10-27 23:45:25,109] Trial 213 finished with values: [0.923854393077893, 0.9722884550761801] and parameters: {'max_features': 'sqrt', 'n_estimators': 350, 'max_depth': 25, 'min_samples_split': 12, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:45:28,538] Trial 214 finished with values: [0.9227077475733494, 0.9718185461616858] and parameters: {'max_features': 'sqrt', 'n_estimators': 460, 'max_depth': 20, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:45:32,113] Trial 215 finished with values: [0.9239766104406403, 0.9731405793169999] and parameters: {'max_features': 'sqrt', 'n_estimators': 453, 'max_depth': 20, 'min_samples_split': 11, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:45:34,309] Trial 216 finished with values: [0.923835853463694, 0.9722067788256448] and parameters: {'max_features': 'log2', 'n_estimators': 278, 'max_depth': None, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': False}.
# [I 2025-10-27 23:45:37,814] Trial 217 finished with values: [0.9078621004733766, 0.9621597791145052] and parameters: {'max_features': None, 'n_estimators': 232, 'max_depth': 20, 'min_samples_split': 12, 'min_samples_leaf': 10, 'bootstrap': False}.
# [I 2025-10-27 23:45:41,418] Trial 218 finished with values: [0.920943699652689, 0.9709940865563987] and parameters: {'max_features': 'sqrt', 'n_estimators': 463, 'max_depth': 15, 'min_samples_split': 13, 'min_samples_leaf': 1, 'bootstrap': True}.
# [I 2025-10-27 23:45:45,055] Trial 219 finished with values: [0.9237909518262412, 0.9732249397914616] and parameters: {'max_features': 'sqrt', 'n_estimators': 473, 'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 2, 'bootstrap': False}.
# Optuna rf: 220 trials en 855.9s
# Optimización completa para modelos seleccionados

# %% [markdown]
# ## Caso 5 — Validación Externa y Estabilidad de Métricas
# Para cada modelo se elige el mejor `trial` y se evalúa con `outer_cv` (5 folds), reportando medias y desviaciones estándar de `F1` y `ROC‑AUC`. Esto permite analizar **robustez** y **variabilidad** del rendimiento.

# %%
# Selección del mejor trial y validación externa (outer CV)
def pick_best_trial(study):
    trials = [t for t in study.trials if t.state == optuna.trial.TrialState.COMPLETE]
    trials_sorted = sorted(trials, key=lambda t: (t.values[0], t.values[1]), reverse=True)
    return trials_sorted[0]

best_models = {}
best_params = {}
cv_summary = {}

for m, st in studies.items():
    bt = pick_best_trial(st)
    params = bt.user_attrs['params']
    est = make_estimator(m, params)
    f1_mean, auc_mean, f1s, aucs = cv_metrics(est, X_train_final, y_train_final, outer_cv)
    best_models[m] = est.fit(X_train_final, y_train_final)
    best_params[m] = params
    cv_summary[m] = {
        'inner_best_f1': float(bt.values[0]),
        'inner_best_auc': float(bt.values[1]),
        'outer_f1_mean': float(np.nanmean(f1s)),
        'outer_f1_std': float(np.nanstd(f1s)),
        'outer_auc_mean': float(np.nanmean(aucs)),
        'outer_auc_std': float(np.nanstd(aucs)),
    }
    print(f"[{m}] inner_f1={bt.values[0]:.4f}, inner_auc={bt.values[1]:.4f} | outer_f1={cv_summary[m]['outer_f1_mean']:.4f}, outer_auc={cv_summary[m]['outer_auc_mean']:.4f}")

print("Validación externa (outer CV) completada")
# Out:
# [lgb] inner_f1=0.9258, inner_auc=0.9773 | outer_f1=0.9258, outer_auc=0.9775
# [xgb] inner_f1=0.9243, inner_auc=0.9767 | outer_f1=0.9246, outer_auc=0.9767
# [rf] inner_f1=0.9247, inner_auc=0.9731 | outer_f1=0.9247, outer_auc=0.9732
# Validación externa (outer CV) completada

# %% [markdown]
# ## Caso 6 — Ensembles (Voting, Weighted Voting, Stacking) y Diversidad
# Se construyen ensembles para combinar fortalezas de los modelos:
# - **Voting soft**: promedio de probabilidades.
# - **Weighted soft voting**: ponderación por AUC externo.
# - **Stacking**: meta-learner `LogisticRegression` sobre `predict_proba`.
# Además, se calcula la **correlación** de probabilidades en test para medir diversidad (menor correlación sugiere mayor complementariedad).

# %%
# Evaluación en test y construcción de ensembles
def evaluate_on_test(name, model):
    y_pred = model.predict(X_test_final)
    f1 = f1_score(y_test_final, y_pred)
    if hasattr(model, 'predict_proba'):
        y_prob = model.predict_proba(X_test_final)[:,1]
        auc = roc_auc_score(y_test_final, y_prob)
    else:
        auc = np.nan
    acc = accuracy_score(y_test_final, y_pred)
    prec = precision_score(y_test_final, y_pred)
    rec = recall_score(y_test_final, y_pred)
    print(f"{name:20s} | F1={f1:.4f} AUC={auc:.4f} ACC={acc:.4f} PREC={prec:.4f} REC={rec:.4f}")
    return {'f1':float(f1), 'auc':float(auc), 'accuracy':float(acc), 'precision':float(prec), 'recall':float(rec)}

results_test = {}
for m, mdl in best_models.items():
    results_test[m] = evaluate_on_test(m, mdl)

# Soft Voting ensemble
estimators = [(m, best_models[m]) for m in selected_models]
voting_soft = VotingClassifier(estimators=estimators, voting='soft', n_jobs=-1)
voting_soft.fit(X_train_final, y_train_final)
results_test['voting_soft'] = evaluate_on_test('voting_soft', voting_soft)

# Weighted Soft Voting (pesos por outer AUC)
weights = [cv_summary[m]['outer_auc_mean'] for m in selected_models]
weights = [w / (sum(weights) + 1e-8) for w in weights]

class WeightedVotingProb:
    def __init__(self, models, weights):
        self.models = models
        self.weights = weights
    def fit(self, X, y):
        return self
    def predict_proba(self, X):
        probs = [mdl.predict_proba(X)[:,1] for mdl in self.models]
        prob = np.zeros(len(probs[0]))
        for p, w in zip(probs, self.weights):
            prob += w * p
        return np.vstack([1-prob, prob]).T
    def predict(self, X):
        return (self.predict_proba(X)[:,1] >= 0.5).astype(int)

weighted_soft = WeightedVotingProb([best_models[m] for m in selected_models], weights)
results_test['weighted_soft'] = evaluate_on_test('weighted_soft', weighted_soft)

# Stacking con meta-learner
stack = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression(max_iter=1000, solver='saga', random_state=SEED),
    stack_method='predict_proba',
    passthrough=False,
    n_jobs=-1
)
stack.fit(X_train_final, y_train_final)
results_test['stacking'] = evaluate_on_test('stacking', stack)

# Diversidad entre modelos base (probabilidades en test)
def diversity(models, X):
    probs = {m: models[m].predict_proba(X)[:,1] for m in models}
    names = list(probs.keys())
    mat = np.zeros((len(names), len(names)))
    for i in range(len(names)):
        for j in range(len(names)):
            mat[i,j] = np.corrcoef(probs[names[i]], probs[names[j]])[0,1]
    return names, mat

names, corr_mat = diversity(best_models, X_test_final)
print('Correlación de probabilidades entre modelos base (test):')
print(pd.DataFrame(corr_mat, index=names, columns=names).round(3))

print("Evaluación en test y ensembles completada")
# Out:
# lgb                  | F1=0.6386 AUC=0.9225 ACC=0.8664 PREC=0.5660 REC=0.7325
# xgb                  | F1=0.6534 AUC=0.9220 ACC=0.8698 PREC=0.5721 REC=0.7616
# rf                   | F1=0.6617 AUC=0.9182 ACC=0.8745 PREC=0.5849 REC=0.7616
# voting_soft          | F1=0.6537 AUC=0.9241 ACC=0.8709 PREC=0.5756 REC=0.7563
# weighted_soft        | F1=0.6556 AUC=0.9241 ACC=0.8720 PREC=0.5785 REC=0.7563
# stacking             | F1=0.6581 AUC=0.9216 ACC=0.8756 PREC=0.5905 REC=0.7430
# Correlación de probabilidades entre modelos base (test):
#        lgb    xgb     rf
# lgb  1.000  0.997  0.972
# xgb  0.997  1.000  0.972
# rf   0.972  0.972  1.000
# Evaluación en test y ensembles completada

# %% [markdown]
# ## Caso 7 — Selección del Modelo Final y Artefactos para Producción
# Se selecciona el modelo final priorizando `F1` y desempate por `ROC‑AUC`. Se consideran señales de **estabilidad** (desviación estándar en outer CV) y **robustez**. Se guardan el modelo y metadatos en `models/`.

# %%
# Selección del modelo final y guardado de artefactos
def pick_final_model(results_test, cv_summary):
    ranking = sorted(results_test.items(), key=lambda kv: (kv[1]['f1'], kv[1]['auc']), reverse=True)
    final_name = ranking[0][0]
    return final_name

final_name = pick_final_model(results_test, cv_summary)
if final_name in best_models:
    final_model = best_models[final_name]
elif final_name == 'voting_soft':
    final_model = voting_soft
elif final_name == 'weighted_soft':
    final_model = weighted_soft
elif final_name == 'stacking':
    final_model = stack
else:
    final_model = voting_soft

# Guardado de modelo y metadatos
models_dir = Path('../models')
models_dir.mkdir(parents=True, exist_ok=True)

model_path = models_dir / 'mejor_modelo_final.pkl'
joblib.dump(final_model, model_path)

metadata = {
    'fecha': datetime.utcnow().isoformat() + 'Z',
    'usa_smote': use_smote,
    'modelos_seleccionados_prev_commit': selected_models,
    'modelo_final': final_name,
    'resultados_test': results_test,
    'resumen_cv_outer': cv_summary,
    'hiperparametros': {m: best_params[m] for m in best_params},
    'weights_soft': [float(w) for w in weights],
    'diversidad_corr_test': pd.DataFrame(corr_mat, index=names, columns=names).round(6).to_dict(),
    'validacion': {
        'outer_cv': {'n_splits': 5, 'shuffle': True, 'random_state': SEED},
        'inner_cv': {'n_splits': 3, 'shuffle': True, 'random_state': SEED+1},
        'multi_objetivo': ['f1','roc_auc'],
        'optuna_trials_por_modelo': 220
    }
}
with open(models_dir / 'metadatos_modelo_final.json', 'w', encoding='utf-8') as f:
    json.dump(metadata, f, ensure_ascii=False, indent=2)

print(f"Modelo final: {final_name} guardado en {model_path}")
# Out:
# Modelo final: rf guardado en ..\models\mejor_modelo_final.pkl

# %% [markdown]
# ## Resumen de Decisiones Técnicas
# - Validación: StratifiedKFold **anidado** (inner para tuning, outer para estabilidad).
# - Optuna: **TPE** (búsqueda bayesiana) + `MedianPruner`, estudio **multi‑objetivo** (F1 y ROC‑AUC).
# - Modelos: LightGBM, XGBoost, RandomForest (top 3 del commit 04).
# - Ensembles: Voting soft, Voting ponderado por AUC, Stacking con `LogisticRegression`.
# - Diversidad: correlación de probabilidades en test entre modelos base.
# - Selección final: maximiza F1, desempata por AUC y considera **robustez** (std en outer CV).
# - Artefactos: modelo y metadatos guardados en `models/`.
